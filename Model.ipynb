# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise je promenjen sa 8 na 0
DATA_PATH = 'audio_speech_actors_01-24/'
SAMPLE_RATE = 48000

data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender','Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join(dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = (int(identifiers[2]))
        if emotion == 8: # promeni surprise sa 8 na 0
            emotion = 0
        if int(identifiers[3]) == 1:
            emotion_intensity = 'normal' 
        else:
            emotion_intensity = 'strong'
        if int(identifiers[6])%2 == 0:
            gender = 'female'
        else:
            gender = 'male'
        
        data = data.append({"Emotion": emotion,
                            "Emotion intensity": emotion_intensity,
                            "Gender": gender,
                            "Path": file_path
                             },
                             ignore_index = True
                          )

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 1440
#   Emotion Emotion intensity Gender  \
# 0       1            normal   male
# 1       1            normal   male
# 2       1            normal   male
# 3       1            normal   male
# 4       2            normal   male
#
#                                                 Path
# 0  audio_speech_actors_01-24/Actor_01\03-01-01-01...
# 1  audio_speech_actors_01-24/Actor_01\03-01-01-01...
# 2  audio_speech_actors_01-24/Actor_01\03-01-01-01...
# 3  audio_speech_actors_01-24/Actor_01\03-01-01-01...
# 4  audio_speech_actors_01-24/Actor_01\03-01-02-01...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %%
#Loading the signals
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 1439/1440 files

# %%
#Splitting the data
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(1147, 144000), Y_train:(1147,)
# X_val:(143, 144000), Y_val:(143,)
# X_test:(150, 144000), Y_test:(150,)
# Number of unique indexes is 1440, out of 1440

# %%
#Augmenting signals by adding AWGN
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i,:]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(data.loc[i,"Emotion"])
        aug_signals.append(augmented_signals[j,:])
        data = data.append(data.iloc[i], ignore_index=True)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
aug_signals = np.stack(aug_signals,axis=0)
X_train = np.concatenate([X_train,aug_signals],axis=0)
aug_labels = np.stack(aug_labels,axis=0)
Y_train = np.concatenate([Y_train,aug_labels])
print('')
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
# Out:
#  Processed 1146/1147 files
# X_train:(3441, 144000), Y_train:(3441,)

# %%
#Calculating melspectograms
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test

print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Calculatin mel spectrograms for train set
#  Processed 3440/3441 files
# Calculatin mel spectrograms for val set
#  Processed 142/143 files
# Calculatin mel spectrograms for test set
#  Processed 149/150 files
# X_train:(3441, 128, 563), Y_train:(3441,)
# X_val:(143, 128, 563), Y_val:(143,)
# X_test:(150, 128, 563), Y_test:(150,)

# %%
#Creating the model
import torch
import torch.nn as nn

class ParallelModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        # Transformer block
        self.transf_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        transf_layer = nn.TransformerEncoderLayer(d_model=64, nhead=4, dim_feedforward=512, dropout=0.4, activation='relu')
        self.transf_encoder = nn.TransformerEncoder(transf_layer, num_layers=4)
        # Linear softmax layer
        self.out_linear = nn.Linear(320,num_emotions)
        self.dropout_linear = nn.Dropout(p=0)
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # conv embedding
        conv_embedding = self.conv2Dblock(x) #(b,channel,freq,time)
        conv_embedding = torch.flatten(conv_embedding, start_dim=1) # do not flatten batch dimension
        # transformer embedding
        x_reduced = self.transf_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(2,0,1) # requires shape = (time,batch,embedding)
        transf_out = self.transf_encoder(x_reduced)
        transf_embedding = torch.mean(transf_out, dim=0)
        # concatenate
        complete_embedding = torch.cat([conv_embedding, transf_embedding], dim=1) 
        # final Linear
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        output_softmax = self.out_softmax(output_logits)
        return output_logits, output_softmax

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %%
#Training 
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
from sklearn.preprocessing import StandardScaler

X_train = np.expand_dims(X_train,1)
X_val = np.expand_dims(X_val,1)
X_test = np.expand_dims(X_test,1)

scaler = StandardScaler()

b,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,c,h,w))

b,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,c,h,w))

b,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,c,h,w))

# %%
EPOCHS=100
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = ParallelModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, predictions = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cpu
# Number of trainable params:  395176
# c:\users\hardi\appdata\local\programs\python\python39\lib\site-packages\torch\nn\modules\transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
#  Epoch 0: iteration 106/107
# Epoch 0 --> loss:2.2881, acc:16.01%, val_loss:2.0382, val_acc:19.58%
#  Epoch 1: iteration 106/107
# Epoch 1 --> loss:2.0811, acc:18.45%, val_loss:1.7533, val_acc:32.17%
#  Epoch 2: iteration 106/107
# Epoch 2 --> loss:2.0249, acc:19.44%, val_loss:1.7364, val_acc:33.57%
#  Epoch 3: iteration 106/107
# Epoch 3 --> loss:1.9820, acc:21.24%, val_loss:1.7896, val_acc:33.57%
#  Epoch 4: iteration 106/107
# Epoch 4 --> loss:1.9639, acc:23.25%, val_loss:1.6629, val_acc:34.97%
#  Epoch 5: iteration 106/107
# Epoch 5 --> loss:1.9485, acc:23.68%, val_loss:1.5539, val_acc:41.96%
#  Epoch 6: iteration 106/107
# Epoch 6 --> loss:1.9310, acc:23.34%, val_loss:1.4857, val_acc:46.15%
#  Epoch 7: iteration 106/107
# Epoch 7 --> loss:1.9123, acc:25.66%, val_loss:1.4740, val_acc:46.15%
#  Epoch 8: iteration 106/107
# Epoch 8 --> loss:1.8812, acc:25.60%, val_loss:1.5885, val_acc:46.85%
#  Epoch 9: iteration 106/107
# Epoch 9 --> loss:1.8711, acc:24.59%, val_loss:1.6939, val_acc:39.16%
#  Epoch 10: iteration 106/107
# Epoch 10 --> loss:1.8538, acc:27.23%, val_loss:1.4462, val_acc:46.85%
#  Epoch 11: iteration 106/107
# Epoch 11 --> loss:1.8526, acc:26.27%, val_loss:1.5797, val_acc:43.36%
#  Epoch 12: iteration 106/107
# Epoch 12 --> loss:1.8203, acc:27.96%, val_loss:1.4580, val_acc:50.35%
#  Epoch 13: iteration 106/107
# Epoch 13 --> loss:1.8097, acc:28.48%, val_loss:1.3467, val_acc:51.75%
#  Epoch 14: iteration 106/107
# Epoch 14 --> loss:1.7900, acc:29.15%, val_loss:1.3365, val_acc:49.65%
#  Epoch 15: iteration 106/107
# Epoch 15 --> loss:1.7862, acc:30.37%, val_loss:1.4363, val_acc:52.45%
#  Epoch 16: iteration 106/107
# Epoch 16 --> loss:1.7919, acc:29.03%, val_loss:1.4282, val_acc:48.95%
#  Epoch 17: iteration 106/107
# Epoch 17 --> loss:1.7593, acc:30.11%, val_loss:1.4891, val_acc:47.55%
#  Epoch 18: iteration 106/107
# Epoch 18 --> loss:1.7393, acc:32.03%, val_loss:1.2942, val_acc:55.94%
#  Epoch 19: iteration 106/107
# Epoch 19 --> loss:1.7483, acc:31.10%, val_loss:1.1634, val_acc:59.44%
#  Epoch 20: iteration 106/107
# Epoch 20 --> loss:1.7258, acc:31.76%, val_loss:1.2979, val_acc:51.75%
#  Epoch 21: iteration 106/107
# Epoch 21 --> loss:1.7203, acc:32.26%, val_loss:1.1774, val_acc:53.15%
#  Epoch 22: iteration 106/107
# Epoch 22 --> loss:1.7000, acc:32.14%, val_loss:1.3357, val_acc:51.75%
#  Epoch 23: iteration 106/107
# Epoch 23 --> loss:1.6994, acc:31.94%, val_loss:1.1994, val_acc:59.44%
#  Epoch 24: iteration 106/107
# Epoch 24 --> loss:1.6856, acc:33.48%, val_loss:1.0960, val_acc:62.94%
#  Epoch 25: iteration 106/107
# Epoch 25 --> loss:1.6736, acc:33.68%, val_loss:1.1358, val_acc:60.14%
#  Epoch 26: iteration 106/107
# Epoch 26 --> loss:1.6743, acc:33.65%, val_loss:1.3078, val_acc:52.45%
#  Epoch 27: iteration 106/107
# Epoch 27 --> loss:1.6707, acc:33.89%, val_loss:1.1974, val_acc:57.34%
#  Epoch 28: iteration 106/107
# Epoch 28 --> loss:1.6474, acc:35.14%, val_loss:1.0274, val_acc:60.84%
#  Epoch 29: iteration 106/107
# Epoch 29 --> loss:1.6382, acc:35.54%, val_loss:1.0718, val_acc:61.54%
#  Epoch 30: iteration 106/107
# Epoch 30 --> loss:1.6318, acc:35.34%, val_loss:1.1949, val_acc:57.34%
#  Epoch 31: iteration 106/107
# Epoch 31 --> loss:1.6140, acc:35.72%, val_loss:1.0054, val_acc:64.34%
#  Epoch 32: iteration 106/107
# Epoch 32 --> loss:1.6233, acc:36.36%, val_loss:0.9603, val_acc:65.73%
#  Epoch 33: iteration 106/107
# Epoch 33 --> loss:1.6061, acc:36.68%, val_loss:1.1078, val_acc:60.14%
#  Epoch 34: iteration 106/107
# Epoch 34 --> loss:1.6110, acc:36.09%, val_loss:1.0434, val_acc:67.13%
#  Epoch 35: iteration 106/107
# Epoch 35 --> loss:1.5692, acc:38.51%, val_loss:1.0810, val_acc:62.94%
#  Epoch 36: iteration 106/107
# Epoch 36 --> loss:1.5766, acc:37.58%, val_loss:0.9472, val_acc:71.33%
#  Epoch 37: iteration 106/107
# Epoch 37 --> loss:1.5511, acc:38.77%, val_loss:0.9392, val_acc:61.54%
#  Epoch 38: iteration 106/107
# Epoch 38 --> loss:1.5487, acc:39.61%, val_loss:0.8837, val_acc:69.23%
#  Epoch 39: iteration 106/107
# Epoch 39 --> loss:1.5475, acc:39.12%, val_loss:0.8161, val_acc:69.93%
#  Epoch 40: iteration 106/107
# Epoch 40 --> loss:1.5602, acc:38.51%, val_loss:0.9592, val_acc:69.23%
#  Epoch 41: iteration 106/107
# Epoch 41 --> loss:1.5396, acc:39.52%, val_loss:1.0303, val_acc:66.43%
#  Epoch 42: iteration 106/107
# Epoch 42 --> loss:1.5176, acc:40.95%, val_loss:1.0342, val_acc:64.34%
#  Epoch 43: iteration 106/107
# Epoch 43 --> loss:1.5017, acc:40.40%, val_loss:0.9024, val_acc:71.33%
#  Epoch 44: iteration 106/107
# Epoch 44 --> loss:1.5145, acc:40.54%, val_loss:0.8796, val_acc:69.93%
#  Epoch 45: iteration 106/107
# Epoch 45 --> loss:1.4890, acc:42.08%, val_loss:0.9701, val_acc:67.13%
#  Epoch 46: iteration 106/107
# Epoch 46 --> loss:1.4891, acc:42.63%, val_loss:1.0112, val_acc:65.03%
#  Epoch 47: iteration 106/107
# Epoch 47 --> loss:1.4869, acc:41.73%, val_loss:0.9420, val_acc:69.23%
#  Epoch 48: iteration 106/107
# Epoch 48 --> loss:1.4600, acc:42.75%, val_loss:0.8376, val_acc:72.03%
#  Epoch 49: iteration 106/107
# Epoch 49 --> loss:1.4456, acc:42.98%, val_loss:0.9689, val_acc:69.93%
#  Epoch 50: iteration 106/107
# Epoch 50 --> loss:1.4644, acc:42.08%, val_loss:1.0769, val_acc:68.53%
#  Epoch 51: iteration 106/107
# Epoch 51 --> loss:1.4454, acc:44.23%, val_loss:1.0730, val_acc:64.34%
#  Epoch 52: iteration 106/107
# Epoch 52 --> loss:1.4336, acc:44.23%, val_loss:1.0375, val_acc:69.23%
#  Epoch 53: iteration 106/107
# Epoch 53 --> loss:1.4366, acc:43.80%, val_loss:0.8867, val_acc:67.83%
#  Epoch 54: iteration 106/107
# Epoch 54 --> loss:1.4291, acc:44.81%, val_loss:0.8477, val_acc:72.03%
#  Epoch 55: iteration 106/107
# Epoch 55 --> loss:1.4219, acc:44.09%, val_loss:0.9140, val_acc:67.83%
#  Epoch 56: iteration 106/107
# Epoch 56 --> loss:1.3994, acc:45.63%, val_loss:0.9746, val_acc:69.23%
#  Epoch 57: iteration 106/107
# Epoch 57 --> loss:1.3960, acc:46.24%, val_loss:0.9650, val_acc:70.63%
#  Epoch 58: iteration 106/107
# Epoch 58 --> loss:1.4076, acc:45.57%, val_loss:0.9842, val_acc:67.13%
#  Epoch 59: iteration 106/107
# Epoch 59 --> loss:1.3835, acc:46.12%, val_loss:1.0113, val_acc:72.03%
#  Epoch 60: iteration 106/107
# Epoch 60 --> loss:1.4018, acc:45.54%, val_loss:0.9134, val_acc:70.63%
#  Epoch 61: iteration 106/107
# Epoch 61 --> loss:1.3690, acc:47.02%, val_loss:1.0643, val_acc:65.03%
#  Epoch 62: iteration 106/107
# Epoch 62 --> loss:1.3631, acc:47.78%, val_loss:1.0609, val_acc:66.43%
#  Epoch 63: iteration 106/107
# Epoch 63 --> loss:1.3696, acc:47.98%, val_loss:1.2114, val_acc:58.74%
#  Epoch 64: iteration 106/107
# Epoch 64 --> loss:1.3601, acc:47.83%, val_loss:0.9675, val_acc:69.23%
#  Epoch 65: iteration 106/107
# Epoch 65 --> loss:1.3657, acc:48.24%, val_loss:1.0808, val_acc:70.63%
#  Epoch 66: iteration 106/107
# Epoch 66 --> loss:1.3276, acc:49.90%, val_loss:1.1182, val_acc:66.43%
#  Epoch 67: iteration 106/107
# Epoch 67 --> loss:1.3478, acc:47.72%, val_loss:1.1993, val_acc:67.83%
#  Epoch 68: iteration 106/107
# Epoch 68 --> loss:1.3305, acc:49.06%, val_loss:0.9982, val_acc:73.43%
#  Epoch 69: iteration 106/107
# Epoch 69 --> loss:1.3085, acc:49.64%, val_loss:0.9854, val_acc:69.93%
#  Epoch 70: iteration 106/107
# Epoch 70 --> loss:1.3129, acc:47.40%, val_loss:0.9331, val_acc:70.63%
#  Epoch 71: iteration 106/107
# Epoch 71 --> loss:1.3008, acc:50.74%, val_loss:1.0811, val_acc:71.33%
#  Epoch 72: iteration 106/107
# Epoch 72 --> loss:1.2988, acc:50.65%, val_loss:1.0354, val_acc:70.63%
#  Epoch 73: iteration 106/107
# Epoch 73 --> loss:1.2880, acc:50.92%, val_loss:1.0201, val_acc:67.83%
#  Epoch 74: iteration 106/107
# Epoch 74 --> loss:1.2800, acc:51.50%, val_loss:1.0062, val_acc:68.53%
#  Epoch 75: iteration 106/107
# Epoch 75 --> loss:1.2629, acc:52.83%, val_loss:1.3866, val_acc:64.34%
#  Epoch 76: iteration 106/107
# Epoch 76 --> loss:1.2599, acc:52.28%, val_loss:1.2624, val_acc:65.73%
#  Epoch 77: iteration 106/107
# Epoch 77 --> loss:1.2699, acc:51.76%, val_loss:1.0440, val_acc:68.53%
#  Epoch 78: iteration 106/107
# Epoch 78 --> loss:1.2713, acc:51.21%, val_loss:1.1194, val_acc:69.23%
#  Epoch 79: iteration 106/107
# Epoch 79 --> loss:1.2436, acc:52.48%, val_loss:1.1138, val_acc:72.73%
#  Epoch 80: iteration 106/107
# Epoch 80 --> loss:1.2312, acc:53.07%, val_loss:1.2197, val_acc:67.83%
#  Epoch 81: iteration 106/107
# Epoch 81 --> loss:1.2263, acc:53.88%, val_loss:1.0517, val_acc:68.53%
#  Epoch 82: iteration 106/107
# Epoch 82 --> loss:1.2428, acc:52.22%, val_loss:1.3298, val_acc:65.73%
#  Epoch 83: iteration 106/107
# Epoch 83 --> loss:1.2136, acc:54.03%, val_loss:1.2540, val_acc:67.83%
#  Epoch 84: iteration 106/107
# Epoch 84 --> loss:1.1949, acc:54.23%, val_loss:1.1736, val_acc:72.73%
#  Epoch 85: iteration 106/107
# Epoch 85 --> loss:1.1810, acc:55.10%, val_loss:1.1382, val_acc:65.73%
#  Epoch 86: iteration 106/107
# Epoch 86 --> loss:1.1955, acc:54.72%, val_loss:0.9892, val_acc:74.13%
#  Epoch 87: iteration 106/107
# Epoch 87 --> loss:1.2027, acc:54.66%, val_loss:1.0275, val_acc:69.93%
#  Epoch 88: iteration 106/107
# Epoch 88 --> loss:1.2136, acc:53.53%, val_loss:1.0987, val_acc:67.13%
#  Epoch 89: iteration 106/107
# Epoch 89 --> loss:1.2064, acc:54.61%, val_loss:1.0177, val_acc:68.53%
#  Epoch 90: iteration 106/107
# Epoch 90 --> loss:1.1639, acc:56.09%, val_loss:1.0167, val_acc:73.43%
#  Epoch 91: iteration 106/107
# Epoch 91 --> loss:1.1549, acc:57.45%, val_loss:0.8847, val_acc:71.33%
#  Epoch 92: iteration 106/107
# Epoch 92 --> loss:1.1629, acc:55.65%, val_loss:1.2401, val_acc:67.83%
#  Epoch 93: iteration 106/107
# Epoch 93 --> loss:1.1245, acc:57.54%, val_loss:1.1745, val_acc:70.63%
#  Epoch 94: iteration 106/107
# Epoch 94 --> loss:1.1370, acc:57.22%, val_loss:1.0708, val_acc:70.63%
#  Epoch 95: iteration 106/107
# Epoch 95 --> loss:1.1479, acc:56.12%, val_loss:1.1469, val_acc:64.34%
#  Epoch 96: iteration 106/107
# Epoch 96 --> loss:1.1356, acc:56.99%, val_loss:1.2406, val_acc:65.73%
#  Epoch 97: iteration 106/107
# Epoch 97 --> loss:1.0682, acc:60.48%, val_loss:1.1414, val_acc:67.83%
#  Epoch 98: iteration 106/107
# Epoch 98 --> loss:1.0822, acc:60.42%, val_loss:1.2835, val_acc:62.24%
#  Epoch 99: iteration 106/107
# Epoch 99 --> loss:1.0727, acc:58.91%, val_loss:1.4306, val_acc:62.24%

# %%
#Saving the model
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_transf_parallel_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_transf_parallel_model.pt')))
# Out:
# Model is saved to C:\Users\hardi\OneDrive\Desktop\Python\Jupyter Notebook\models\cnn_transf_parallel_model.pt

# %%
#Loading the Model
LOAD_PATH = os.path.join(os.getcwd(),'models')
model = ParallelModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_transf_parallel_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_transf_parallel_model.pt')))
# Out:
# Model is loaded from C:\Users\hardi\OneDrive\Desktop\Python\Jupyter Notebook\models\cnn_transf_parallel_model.pt
# c:\users\hardi\appdata\local\programs\python\python39\lib\site-packages\torch\nn\modules\transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
#Testing
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 1.381
# Test accuracy is 62.67%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %%
#Plot loss
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])
